# %% [markdown]
# # Demo: `Tracks` and `Playlist`
#
# Here we'll:
#
# * Search for tracks using `Tracks.search`.
# * See the search results from the dict-like `tracks` instance
# * Display the search results in a pandas DataFrame.
# * Create a playlist called "my_test_playlist" with the selected tracks.
# * Get the URL of the newly created playlist.
# * Delete a playlist
# * Instantiate a `Playlist` object using a URL.
# * Look at audio features aof this playlist

# %% [markdown]
# Import the necessary classes from the sung.base module

# %%
from sung.base import Tracks, Playlist

# %% [markdown]
# Search for tracks with the query 'Love', limiting the results to 7
# This will return a Tracks object containing the search results

# %%
tracks = Tracks.search(query='Love', limit=7)

# %% [markdown]
# You can also make a `tracks` object by passing a list of track IDs or urls

# %%
track_ids = [
    '1vrd6UOGamcKNGnSHJQlSt',
    '3CeCwYWvdfXbZLXFhBrbnf',
    '1dGr1c8CrMLDpV6mPbImSI',
    '0u2P5u6lvoDfwTYjAADbn4',
    'https://open.spotify.com/track/6nGeLlakfzlBcFdZXteDq7',  # url
    'https://open.spotify.com/track/6dBUzqjtbnIa1TwYbyw5CM',   # url
    'spotify:track:7hR22TOX3RorxJPcsz5Wbo',  # uri
]

tracks = Tracks(track_ids)

# %% [markdown]
# `tracks` is a `Mapping` (that means "dict-like"), so you can do what you do with dicts...

# %% [markdown]
# Like listing the tracks' keys (IDs)

# %%
list(tracks)
# Out:
# ['1vrd6UOGamcKNGnSHJQlSt',
#  '3CeCwYWvdfXbZLXFhBrbnf',
#  '1dGr1c8CrMLDpV6mPbImSI',
#  '0u2P5u6lvoDfwTYjAADbn4',
#  '6nGeLlakfzlBcFdZXteDq7',
#  '6dBUzqjtbnIa1TwYbyw5CM',
#  '7hR22TOX3RorxJPcsz5Wbo']

# %% [markdown]
# Like Accessing the value of a track for a given key.
# The value is a bunch of metadata about the track.

# %%
track_metadata = tracks['1dGr1c8CrMLDpV6mPbImSI']  # get metadata of track via it's id
assert isinstance(track_metadata, dict)
sorted(track_metadata)
# Out:
# ['album',
#  'artists',
#  'available_markets',
#  'disc_number',
#  'duration_ms',
#  'explicit',
#  'external_ids',
#  'external_urls',
#  'href',
#  'id',
#  'is_local',
#  'name',
#  'popularity',
#  'preview_url',
#  'track_number',
#  'type',
#  'uri']

# %% [markdown]
# But we also have extras over normal dicts.
#
# We can get metadata of a track via it's index:

# %%
track_metadata = tracks[2]

# %%
list_of_track_metadatas = tracks[['6dBUzqjtbnIa1TwYbyw5CM', '1vrd6UOGamcKNGnSHJQlSt']]  # get metadata of tracks via a list of ids

# %%
list_of_track_metadatas = tracks[2:4]  # get metadata of tracks via a slice of ids

# %% [markdown]
# ## Display the search results in a pandas DataFrame

# %% [markdown]
# Display the search results in a pandas DataFrame
# The dataframe method converts the track metadata into a DataFrame for easy viewing.
#
# (Note, you can also use the tracks.dataframe(keys, front_columns=...) to retrieve a data table with more control.)

# %%
tracks.data
# Out:
# Search Results:
#                                                  name  duration_ms  \
# id
# 1vrd6UOGamcKNGnSHJQlSt                     Love Story       235266
# 3CeCwYWvdfXbZLXFhBrbnf  Love Story (Taylor’s Version)       235766
# 1dGr1c8CrMLDpV6mPbImSI                          Lover       221306
# 0u2P5u6lvoDfwTYjAADbn4           lovely (with Khalid)       200185
# 6nGeLlakfzlBcFdZXteDq7                     Love Story       316280
# 6dBUzqjtbnIa1TwYbyw5CM                    Lovers Rock       213920
# 7hR22TOX3RorxJPcsz5Wbo                  Love Somebody       204828
#
#                         popularity  explicit                      id  \
# id
# 1vrd6UOGamcKNGnSHJQlSt          62     False  1vrd6UOGamcKNGnSHJQlSt
# 3CeCwYWvdfXbZLXFhBrbnf          76     False  3CeCwYWvdfXbZLXFhBrbnf
# 1dGr1c8CrMLDpV6mPbImSI          84     False  1dGr1c8CrMLDpV6mPbImSI
# 0u2P5u6lvoDfwTYjAADbn4          86     False  0u2P5u6lvoDfwTYjAADbn4
# 6nGeLlakfzlBcFdZXteDq7          74     False  6nGeLlakfzlBcFdZXteDq7
# 6dBUzqjtbnIa1TwYbyw5CM          85     False  6dBUzqjtbnIa1TwYbyw5CM
# 7hR22TOX3RorxJPcsz5Wbo          86     False  7hR22TOX3RorxJPcsz5Wbo
#
#                                                                     album  \
# id
# 1vrd6UOGamcKNGnSHJQlSt  {'album_type': 'album', 'artists': [{'external...
# 3CeCwYWvdfXbZLXFhBrbnf  {'album_type': 'single', 'artists': [{'externa...
# 1dGr1c8CrMLDpV6mPbImSI  {'album_type': 'album', 'artists': [{'external...
# 0u2P5u6lvoDfwTYjAADbn4  {'album_type': 'single', 'artists': [{'externa...
# 6nGeLlakfzlBcFdZXteDq7  {'album_type': 'album', 'artists': [{'external...
# 6dBUzqjtbnIa1TwYbyw5CM  {'album_type': 'album', 'artists': [{'external...
# 7hR22TOX3RorxJPcsz5Wbo  {'album_type': 'single', 'artists': [{'externa...
#
#                                                                   artists  \
# id
# 1vrd6UOGamcKNGnSHJQlSt  [{'external_urls': {'spotify': 'https://open.s...
# 3CeCwYWvdfXbZLXFhBrbnf  [{'external_urls': {'spotify': 'https://open.s...
# 1dGr1c8CrMLDpV6mPbImSI  [{'external_urls': {'spotify': 'https://open.s...
# 0u2P5u6lvoDfwTYjAADbn4  [{'external_urls': {'spotify': 'https://open.s...
# 6nGeLlakfzlBcFdZXteDq7  [{'external_urls': {'spotify': 'https://open.s...
# 6dBUzqjtbnIa1TwYbyw5CM  [{'external_urls': {'spotify': 'https://open.s...
# 7hR22TOX3RorxJPcsz5Wbo  [{'external_urls': {'spotify': 'https://open.s...
#
#                                                         available_markets  \
# id
# 1vrd6UOGamcKNGnSHJQlSt                                           [CA, US]
# 3CeCwYWvdfXbZLXFhBrbnf  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 1dGr1c8CrMLDpV6mPbImSI  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 0u2P5u6lvoDfwTYjAADbn4  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 6nGeLlakfzlBcFdZXteDq7  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 6dBUzqjtbnIa1TwYbyw5CM  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
# 7hR22TOX3RorxJPcsz5Wbo  [AR, AU, AT, BE, BO, BR, BG, CA, CL, CO, CR, C...
#
#                         disc_number              external_ids  \
# id
# 1vrd6UOGamcKNGnSHJQlSt            1  {'isrc': 'USCJY0803275'}
# 3CeCwYWvdfXbZLXFhBrbnf            1  {'isrc': 'USUG12100342'}
# 1dGr1c8CrMLDpV6mPbImSI            1  {'isrc': 'USUG11901473'}
# 0u2P5u6lvoDfwTYjAADbn4            1  {'isrc': 'USUM71804190'}
# 6nGeLlakfzlBcFdZXteDq7            1  {'isrc': 'FRUM71400048'}
# 6dBUzqjtbnIa1TwYbyw5CM            1  {'isrc': 'USHM21438143'}
# 7hR22TOX3RorxJPcsz5Wbo            1  {'isrc': 'USUG12406387'}
#
#                                                             external_urls  \
# id
# 1vrd6UOGamcKNGnSHJQlSt  {'spotify': 'https://open.spotify.com/track/1v...
# 3CeCwYWvdfXbZLXFhBrbnf  {'spotify': 'https://open.spotify.com/track/3C...
# 1dGr1c8CrMLDpV6mPbImSI  {'spotify': 'https://open.spotify.com/track/1d...
# 0u2P5u6lvoDfwTYjAADbn4  {'spotify': 'https://open.spotify.com/track/0u...
# 6nGeLlakfzlBcFdZXteDq7  {'spotify': 'https://open.spotify.com/track/6n...
# 6dBUzqjtbnIa1TwYbyw5CM  {'spotify': 'https://open.spotify.com/track/6d...
# 7hR22TOX3RorxJPcsz5Wbo  {'spotify': 'https://open.spotify.com/track/7h...
#
#                                                                      href  \
# id
# 1vrd6UOGamcKNGnSHJQlSt  https://api.spotify.com/v1/tracks/1vrd6UOGamcK...
# 3CeCwYWvdfXbZLXFhBrbnf  https://api.spotify.com/v1/tracks/3CeCwYWvdfXb...
# 1dGr1c8CrMLDpV6mPbImSI  https://api.spotify.com/v1/tracks/1dGr1c8CrMLD...
# 0u2P5u6lvoDfwTYjAADbn4  https://api.spotify.com/v1/tracks/0u2P5u6lvoDf...
# 6nGeLlakfzlBcFdZXteDq7  https://api.spotify.com/v1/tracks/6nGeLlakfzlB...
# 6dBUzqjtbnIa1TwYbyw5CM  https://api.spotify.com/v1/tracks/6dBUzqjtbnIa...
# 7hR22TOX3RorxJPcsz5Wbo  https://api.spotify.com/v1/tracks/7hR22TOX3Ror...
#
#                         is_local  \
# id
# 1vrd6UOGamcKNGnSHJQlSt     False
# 3CeCwYWvdfXbZLXFhBrbnf     False
# 1dGr1c8CrMLDpV6mPbImSI     False
# 0u2P5u6lvoDfwTYjAADbn4     False
# 6nGeLlakfzlBcFdZXteDq7     False
# 6dBUzqjtbnIa1TwYbyw5CM     False
# 7hR22TOX3RorxJPcsz5Wbo     False
#
#                                                               preview_url  \
# id
# 1vrd6UOGamcKNGnSHJQlSt                                               None
# 3CeCwYWvdfXbZLXFhBrbnf                                               None
# 1dGr1c8CrMLDpV6mPbImSI                                               None
# 0u2P5u6lvoDfwTYjAADbn4                                               None
# 6nGeLlakfzlBcFdZXteDq7                                               None
# 6dBUzqjtbnIa1TwYbyw5CM  https://p.scdn.co/mp3-preview/922a42db5aa8f8d3...
# 7hR22TOX3RorxJPcsz5Wbo                                               None
#
#                         track_number   type  \
# id
# 1vrd6UOGamcKNGnSHJQlSt             3  track
# 3CeCwYWvdfXbZLXFhBrbnf             1  track
# 1dGr1c8CrMLDpV6mPbImSI             3  track
# 0u2P5u6lvoDfwTYjAADbn4             1  track
# 6nGeLlakfzlBcFdZXteDq7             3  track
# 6dBUzqjtbnIa1TwYbyw5CM             9  track
# 7hR22TOX3RorxJPcsz5Wbo             1  track
#
#                                                          uri
# id
# 1vrd6UOGamcKNGnSHJQlSt  spotify:track:1vrd6UOGamcKNGnSHJQlSt
# 3CeCwYWvdfXbZLXFhBrbnf  spotify:track:3CeCwYWvdfXbZLXFhBrbnf
# 1dGr1c8CrMLDpV6mPbImSI  spotify:track:1dGr1c8CrMLDpV6mPbImSI
# 0u2P5u6lvoDfwTYjAADbn4  spotify:track:0u2P5u6lvoDfwTYjAADbn4
# 6nGeLlakfzlBcFdZXteDq7  spotify:track:6nGeLlakfzlBcFdZXteDq7
# 6dBUzqjtbnIa1TwYbyw5CM  spotify:track:6dBUzqjtbnIa1TwYbyw5CM
# 7hR22TOX3RorxJPcsz5Wbo  spotify:track:7hR22TOX3RorxJPcsz5Wbo

# %% [markdown]
# ## Make a playlist

# %% [markdown]
# Select three tracks from the search results
# Here, we select the first three track IDs from the search results

# %%
selected_track_ids = tracks.track_ids[:3]
print("\nSelected Track IDs:")
print(selected_track_ids)
# Out:
# Selected Track IDs:
# ['6FjErEvVbuC32xi4QJUXM0', '1vrd6UOGamcKNGnSHJQlSt', '3CeCwYWvdfXbZLXFhBrbnf']

# %% [markdown]
# Create a new playlist named 'my_test_playlist' with the selected tracks
# The create_from_track_list class method creates a new playlist with the given tracks

# %%
playlist = Playlist.create_from_track_list(
    track_list=selected_track_ids,
    playlist_name='my_test_playlist'
)
print(f"\nPlaylist '{playlist.playlist_id}' created successfully.")
# Out:
# Playlist '7BZcFvIWUnVzvZ5wpVt9cD' created successfully.

# %% [markdown]
# Get the playlist URL of the newly created playlist (go check it out!)

# %%
playlist.playlist_url
# Out:
# 'https://open.spotify.com/playlist/7BZcFvIWUnVzvZ5wpVt9cD'

# %% [markdown]
# ## Delete a playlist
#
# We purposely tried to make deleting a playlist not as easy as the other actions.
# So we didn't attach a delete method to the playlist instance, but put this in a
# separate function you have to import.
# Also, we made that function verbose, and asking for confirmation by default.
# (But there's arguments to control that, so you can use `functools.partial` to
# make your own cowboy (not speaking and not asking for permission) version).

# %%
from sung import delete_playlist

delete_playlist(playlist.playlist_id)

# %% [markdown]
# Instantiate a Playlist object using a URL.
# This allows you to interact with the playlist, such as accessing its tracks.

# %%
top50_global_url = 'https://open.spotify.com/playlist/37i9dQZEVXbMDoHDwVN2tF?si=d6e0c7bc8f59473b'
top50_playlist = Playlist(top50_global_url)
df = top50_playlist.data
df['first_artist'] = df['artists'].apply(lambda x: x[0]['name'])
df['name_and_first_artist'] = df['name'] + ' - ' + df['first_artist']
top_5_tracks = top50_playlist.data.iloc[:5].name_and_first_artist
top_5_tracks
# Out:
# id
# 2plbrEY59IikOBgBGLjaoe          Die With A Smile - Lady Gaga
# 5vNRhkKd0yEAg8suGBpjeY                           APT. - ROSÉ
# 6dOtVTDdiauQNBQEDOtlAB    BIRDS OF A FEATHER - Billie Eilish
# 7ne4VBA60CxGM75vw0EYad        That’s So True - Gracie Abrams
# 7tI8dRuH2Yc6RuoTjxo4dU                           Who - Jimin
# Name: name_and_first_artist, dtype: object

# %% [markdown]
# ## Audio features

# %%
import pandas as pd

print(f"{top50_playlist.audio_features_df.shape=}")
top50_playlist.audio_features_df.iloc[0]
# Out:
# top50_playlist.audio_features_df.shape=(50, 17)
# danceability                                                    0.521
# energy                                                          0.592
# key                                                                 6
# loudness                                                       -7.777
# mode                                                                0
# speechiness                                                    0.0304
# acousticness                                                    0.308
# instrumentalness                                                  0.0
# liveness                                                        0.122
# valence                                                         0.535
# tempo                                                         157.969
# type                                                   audio_features
# uri                              spotify:track:2plbrEY59IikOBgBGLjaoe
# track_href          https://api.spotify.com/v1/tracks/2plbrEY59Iik...
# analysis_url        https://api.spotify.com/v1/audio-analysis/2plb...
# duration_ms                                                    251668
# time_signature                                                      3
# Name: 2plbrEY59IikOBgBGLjaoe, dtype: object

# %%
import seaborn as sns
from matplotlib import pyplot as plt

df = pd.merge(top50_playlist.data, top50_playlist.audio_features_df, left_index=True, right_index=True)
# scatter plot with danceability and energy, colored by popularity, with size as loudness
sns.scatterplot(data=df, x='danceability', y='energy', hue='popularity', size='loudness')

# Move the legend outside the plot
plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left');

# %%
import seaborn as sns

sns.pairplot(top50_playlist.audio_features_df[['danceability', 'energy', 'loudness', 'speechiness', 'acousticness', 'instrumentalness', 'liveness', 'valence', 'tempo']])

# %% [markdown]
# ## Audio analysis

# %%
audio_analysis = top50_playlist.audio_analysis(next(iter(top50_playlist)))

# %%
type(audio_analysis)
# Out:
# dict

# %%
list(audio_analysis)
# Out:
# ['meta', 'track', 'bars', 'beats', 'sections', 'segments', 'tatums']

# %%
audio_analysis['meta']
# Out:
# {'analyzer_version': '4.0.0',
#  'platform': 'Linux',
#  'detailed_status': 'OK',
#  'status_code': 0,
#  'timestamp': 1723785476,
#  'analysis_time': 5.78793,
#  'input_process': 'libvorbisfile L+R 44100->22050'}

# %%
audio_analysis['track']
# Out:
# {'num_samples': 5549270,
#  'duration': 251.66757,
#  'sample_md5': '',
#  'offset_seconds': 0,
#  'window_seconds': 0,
#  'analysis_sample_rate': 22050,
#  'analysis_channels': 1,
#  'end_of_fade_in': 0.2034,
#  'start_of_fade_out': 241.98096,
#  'loudness': -7.863,
#  'tempo': 158.005,
#  'tempo_confidence': 0.501,
#  'time_signature': 3,
#  'time_signature_confidence': 1.0,
#  'key': 6,
#  'key_confidence': 0.253,
#  'mode': 0,
#  'mode_confidence': 0.452,
#  'codestring': 'eJxVmgcC3DgOBL-iJzCH_3_sqprjtW-jyZEoIjUaIPtcc7d7yle-eUq9586v3vb1_DBL-Q7_3tpWub3zW6_8uGvpZ47z1XPOt1pvdY2zvjZ6-0a7Y696-9dLOV9ve-5Zm2u24nDsyWpfP_zKw_XsfsbXbxlf25s13MAoLOXDbY25eY4P7dp6aWeub-y-Pp-tixGrl2-v1erY95tjNx8tc9_G0OfXvaWy5Y-HBiPX5dHtBu-qq9YzeGnvxbbGrvtcJK_t8Hrvp1-2cPiYos_Rz4f045t77dldoqHBWtYc5c5-v3v4St9nIs-9_KJenqQbUWuds6HmOu9AuxVdsfJEofNufkaffH2xcVTEg22jmnp3a4jEkM9FITzCLjRJcds8sSbL9aXqVi1n9r4Zbw3KGvdef5_lKb619_l5UFg9t652Buuvstw9wrVyHEf3bdw-DhtF5VX7lIYqfH-du2LmgQL4Ho-er1VknbVUxjHIWWuM6Am7qdfR7zk8fvjKd25DyW2w_HFRDFlaq3rc_bkNbjbL_rArn1cVK8psZb
uTDu9h4qfCvIVZ7ecseFtj7t9M0zWSdeFAaKSkr1tqvuXyiZRERxEKrDUzjWiSiO3KUi2vLNFII4cj_SgIK-kafGtZgpfArYXVKeBm6G0fi4IA_apaUz5_TaskBok8JQAAdvD2JEibY7O3tUufbBPpcanxfZoTFDBX5nC4vUzoO7qgo28Q0dnRPOlpx_rk7LyM5GaSMfW4lCdNnbXHbsFYDpnUlxPkdzcMGRTOkfwdwCuMBgJdkRMHd1Ed1rGzECAAqcCw5r6NJx_8cAJKXOgTYTVSx91IEfTFnBU8HFbdmDeXdw1-zOsL2yqLR3HFdubpExXBcznHgletrb-eARRUSFgJEdxdp2ZJJ2apRXDXu ...
#  'rhythm_version': 1.0}

# %%
from lkj import truncate_dict_values

print(f"{len(audio_analysis['bars'])=})")
truncate_dict_values(audio_analysis['bars'])
# Out:
# len(audio_analysis['bars'])=211)
# [{'start': 1.36936, 'duration': 1.1373, 'confidence': 0.506},
#  {'start': 2.50666, 'duration': 1.14286, 'confidence': 0.037}]

# %%
print(f"{len(audio_analysis['beats'])=})")
truncate_dict_values(audio_analysis['beats'])
# Out:
# len(audio_analysis['beats'])=639)
# [{'start': 0.598, 'duration': 0.39454, 'confidence': 0.786},
#  {'start': 0.99254, 'duration': 0.37682, 'confidence': 0.461}]

# %%
print(f"{len(audio_analysis['sections'])=})")
truncate_dict_values(audio_analysis['sections'])
# Out:
# len(audio_analysis['sections'])=10)
# [{'start': 0.0,
#   'duration': 9.72348,
#   'confidence': 1.0,
#   'loudness': -22.269,
#   'tempo': 158.348,
#   'tempo_confidence': 0.353,
#   'key': 1,
#   'key_confidence': 0.03,
#   'mode': 0,
#   'mode_confidence': 0.567,
#   'time_signature': 3,
#   'time_signature_confidence': 1.0},
#  {'start': 9.72348,
#   'duration': 29.24311,
#   'confidence': 0.606,
#   'loudness': -11.712,
#   'tempo': 158.114,
#   'tempo_confidence': 0.364,
#   'key': 9,
#   'key_confidence': 0.217,
#   'mode': 1,
#   'mode_confidence': 0.472,
#   'time_signature': 3,
#   'time_signature_confidence': 1.0}]

# %%
print(f"{len(audio_analysis['segments'])=})")
truncate_dict_values(audio_analysis['segments'])
# Out:
# len(audio_analysis['segments'])=780)
# [{'start': 0.0,
#   'duration': 0.2034,
#   'confidence': 0.0,
#   'loudness_start': -60.0,
#   'loudness_max_time': 0.0,
#   'loudness_max': -60.0,
#   'loudness_end': 0.0,
#   'pitches': [1.0, 1.0],
#   'timbre': [0.0, 171.13]},
#  {'start': 0.2034,
#   'duration': 0.41234,
#   'confidence': 1.0,
#   'loudness_start': -60.0,
#   'loudness_max_time': 0.05445,
#   'loudness_max': -22.196,
#   'loudness_end': 0.0,
#   'pitches': [0.082, 0.554],
#   'timbre': [33.758, 53.096]}]

# %%
print(f"{len(audio_analysis['tatums'])=})")
truncate_dict_values(audio_analysis['tatums'])
# Out:
# len(audio_analysis['tatums'])=1278)
# [{'start': 0.598, 'duration': 0.19727, 'confidence': 0.786},
#  {'start': 0.79527, 'duration': 0.19727, 'confidence': 0.786}]

# %%
from lkj import truncate_dict_values

truncate_dict_values(audio_analysis, max_list_size=2)
# Out:
# {'meta': {'analyzer_version': '4.0.0',
#   'platform': 'Linux',
#   'detailed_status': 'OK',
#   'status_code': 0,
#   'timestamp': 1476616359,
#   'analysis_time': 109.6869,
#   'input_process': 'libvorbisfile L+R 44100->22050'},
#  'track': {'num_samples': 15594936,
#   'duration': 707.25336,
#   'sample_md5': '',
#   'offset_seconds': 0,
#   'window_seconds': 0,
#   'analysis_sample_rate': 22050,
#   'analysis_channels': 1,
#   'end_of_fade_in': 2.82703,
#   'start_of_fade_out': 693.6381,
#   'loudness': -10.355,
#   'tempo': 106.396,
#   'tempo_confidence': 0.595,
#   'time_signature': 4,
#   'time_signature_confidence': 0.904,
#   'key': 5,
#   'key_confidence': 0.049,
#   'mode': 0,
#   'mode_confidence': 0.228,
#   'codestring': 'eJw1nQmS5LqOBK9SRxB38v4X63BHtv2...y2bmBs1qBYvtiECKLDlx_oH4Y3DGg==',
#   'code_version': 3.15,
#   'echoprintstring': 'eJzcnQ2u7DhzZLckUaRILkf82_8S5oT...av23MzLxruBTa5AgsAdSL_-A1nrtTE=',
#   'echoprint_version': 4.12,
#   'synchstring': 'eJx9mAuS5DgIRK_iI1h_6_4XW_IlclV...OPN79PfjNMgH2A-QVgPFZR_AHMBU_o=',
#   'synch_version': 1.0,
#   'rhythmstring': 'eJyNnVmSJEmOQ68SR9B9uf_FxogHqme...EXgaMRt5h7-gy4yclWmWjb8_wC55QRT',
#   'rhythm_version': 1.0},
#  'bars': [{'start': 2.64511, 'duration': 2.23768, 'confidence': 0.825},
#   {'start': 4.88279, 'duration': 2.16451, 'confidence': 0.352}],
#  'beats': [{'start': 0.9181, 'duration': 0.58698, 'confidence': 0.683},
#   {'start': 1.50508, 'duration': 0.57369, 'confidence': 0.572}],
#  'sections': [{'start': 0.0,
#    'duration': 11.51788,
#    'confidence': 1.0,
#    'loudness': -20.409,
#    'tempo': 108.121,
#    'tempo_confidence': 0.728,
#    'key': 6,
#    'key_confidence': 0.162,
#    'mode': 1,
#    'mode_confidence': 0.478,
#    'time_signature': 4,
#    'time_signature_confidence': 0.1},
#   {'start': 11.51788,
#    'duration': 30.61314,
#    'confidence': 0.731,
#    'loudness': -12.171,
#    'tempo': 107.882,
#    'tempo_confidence': 0.499,
#    'key': 10,
#    'key_confidence': 0.429,
#    'mode': 0,
#    'mode_confidence': 0.387,
#    'time_signature': 4,
#    'time_signature_confidence': 0.467}],
#  'segments': [{'start': 0.0,
#    'duration': 0.60957,
#    'confidence': 0.0,
#    'loudness_start': -60.0,
#    'loudness_max_time': 0.5863,
#    'loudness_max': -56.103,
#    'loudness_end': 0.0,
#    'pitches': [0.8, 0.511],
#    'timbre': [0.116, 169.016]},
#   {'start': 0.60957,
#    'duration': 0.60376,
#    'confidence': 1.0,
#    'loudness_start': -55.895,
#    'loudness_max_time': 0.03504,
#    'loudness_max': -36.652,
#    'loudness_end': 0.0,
#    'pitches': [0.434, 0.38],
#    'timbre': [13.111, 157.189]}],
#  'tatums': [{'start': 0.9181, 'duration': 0.29349, 'confidence': 0.683},
#   {'start': 1.21159, 'duration': 0.29349, 'confidence': 0.683}]}
